# %% [markdown]
# # Multinomial Logistic Regression
# This is an example of multinomial logistic regression using a data set from UCI's [machine learning repository](https://archive.ics.uci.edu/ml/datasets/student+performance#). You can download the *sutdent.zip* file [here](https://archive.ics.uci.edu/ml/machine-learning-databases/00320/).The response variable is categorical describing students who passed, failed, or received an incomplete for a mathematics. Some data transformation was necessary in the response because the data was given as score (0-20), where scores greater than or equal to 10 are passing, less than 10 are failing, and a score of 0 results in an incomplete. After transforamation the response variable was multinomial; 0 = fail, 1 = pass, and 2 = incomplete.
#
# ## Load data into DataFrame:

# %%
import time
import numpy as np
import pandas as pd
from statsmodels.stats.outliers_influence import variance_inflation_factor as vif
from sklearn.model_selection import train_test_split, cross_val_score
from sklearn.linear_model import LogisticRegression
from sklearn.utils.extmath import cartesian
from sklearn import metrics
from sklearn import preprocessing

df = pd.read_csv('student-por2.csv')
df = pd.get_dummies(df, drop_first=True)

# %% [markdown]
# ## Correlation Matrix
# Next, we review the correlation matrix to see which variables are highly correlated. Assesing this metric will help us identify variable that potentially will inflate the variance and thus should be removed from the model. **Note** If you wish to view the full correlation matrix, remove the comment from the below syntax and open *corr_matrix.csv* in your current working directory.

# %%
corr_mat = df.corr(method = 'pearson')
#corr_mat.to_csv("corr_matrix_pear.csv")
corr_mat
# Out:
#                         age      Medu      Fedu  traveltime  studytime  \
# age                1.000000 -0.107832 -0.121050    0.034490  -0.008415
# Medu              -0.107832  1.000000  0.647477   -0.265079   0.097006
# Fedu              -0.121050  0.647477  1.000000   -0.208288   0.050400
# traveltime         0.034490 -0.265079 -0.208288    1.000000  -0.063154
# studytime         -0.008415  0.097006  0.050400   -0.063154   1.000000
# failures           0.319968 -0.172210 -0.165915    0.097730  -0.147441
# famrel            -0.020559  0.024421  0.020256   -0.009521  -0.004127
# freetime          -0.004910 -0.019686  0.006841    0.000937  -0.068829
# goout              0.112805  0.009536  0.027690    0.057454  -0.075442
# Dalc               0.134768 -0.007018  0.000061    0.092824  -0.137585
# Walc               0.086357 -0.019766  0.038445    0.057007  -0.214925
# health            -0.008750  0.004614  0.044910   -0.048261  -0.056433
# absences           0.149998 -0.008577  0.029859   -0.008149  -0.118389
# G1                -0.174322  0.260472  0.217501   -0.154120   0.260875
# G2                -0.107119  0.264035  0.225139   -0.154489   0.240498
# G3                -0.106505  0.240151  0.211800   -0.127173   0.249789
# school_MS          0.087170 -0.254787 -0.209806    0.252936  -0.137857
# sex_M             -0.043662  0.119127  0.083913    0.040880  -0.206214
# address_U         -0.025848  0.190320  0.141493   -0.344902   0.062023
# famsize_LE3       -0.002470 -0.014325 -0.039538    0.012794  -0.010945
# Pstatus_T         -0.005631 -0.057174 -0.031856    0.040633  -0.008748
# Mjob_health       -0.100237  0.261215  0.140789   -0.104606  -0.018978
# Mjob_other         0.038776 -0.224335 -0.197974    0.034973  -0.004220
# Mjob_services     -0.034880  0.130272  0.104368   -0.072497   0.029369
# Mjob_teacher      -0.046692  0.449847  0.312130   -0.097961   0.035469
# Fjob_health       -0.103504  0.155576  0.227081   -0.089981   0.096471
# Fjob_other         0.058406 -0.117551 -0.216447    0.101121  -0.035826
# reason_home       -0.080719 -0.021748 -0.055329 -0.014189  0.060085
# reason_other       0.000204  0.015373 -0.032606  0.002870  0.121225
# reason_reputation -0.111185  0.034705 -0.009839 -0.004559 -0.091842
# guardian_mother   -0.056527  0.012507  0.022349  0.042602 -0.093064
# guardian_other     0.234027 -0.067365  0.033823  0.018432  0.112437
# schoolsup_yes     -0.000745 -0.012038 -0.015611 -0.058124 -0.028076
# famsup_yes        -0.006982  0.015228  0.003764  0.017262 -0.016844
# paid_yes           0.069416  0.031937 -0.049574 -0.006683  0.051986
# activities_yes     0.000561  0.057597  0.150329  0.088582  0.022592
# nursery_yes       -0.069241  0.041055 -0.007096  0.018679 -0.078376
# higher_yes        -0.309400  0.048239 -0.102618 -0.069105 -0.131663
# internet_yes      -0.095330  0.082214  0.063268  0.092869  0.042811
# romantic_yes       0.069901 -0.044920  0.027112 -0.000520  0.062042
#
#                        ...       guardian_mother  guardian_other  \
# age                    ...             -0.048726        0.330353
# Medu                   ...              0.091562       -0.101123
# Fedu                   ...             -0.044450       -0.066684
# traveltime             ...             -0.066130        0.090497
# studytime              ...             -0.018076        0.006440
# failures               ...             -0.056527        0.234027
# famrel                 ...              0.012507       -0.067365
# freetime               ...              0.022349        0.033823
# goout                  ...              0.042602        0.018432
# Dalc                   ...             -0.093064        0.112437
# Walc                   ...             -0.006809       -0.002456
# health                 ...              0.009374        0.008833
# absences               ...              0.005036        0.155654
# G1                     ...             -0.005619       -0.125517
# G2                     ...              0.001851       -0.105238
# G3                     ...             -0.004415       -0.080729
# school_MS              ...             -0.052590       -0.016982
# sex_M                  ...             -0.030708       -0.010358
# address_U              ...              0.015464       -0.035192
# famsize_LE3            ...              0.017646       -0.015673
# Pstatus_T              ...             -0.070786       -0.114559
# Mjob_health            ...             -0.034105       -0.049186
# Mjob_other             ...             -0.109205        0.086726
# Mjob_services          ...              0.063294       -0.087019
# Mjob_teacher           ...              0.123488       -0.051397
# Fjob_health            ...             -0.038682       -0.049776
# Fjob_other             ...              0.086263        0.087079
# Fjob_services          ...             -0.059257       -0.062630
# Fjob_teacher           ...             -0.003512       -0.062930
# reason_home            ...              0.004316        0.023901
# reason_other           ...              0.016315       -0.071564
# reason_reputation      ...             -0.018306       -0.031080
# guardian_mother        ...              1.000000       -0.397690
# guardian_other         ...             -0.397690        1.000000
# schoolsup_yes          ...             -0.018390       -0.026798
# famsup_yes             ...             -0.034759        0.050158
# paid_yes               ...              0.037643        0.040941
# activities_yes         ...              0.041487       -0.024076
# nursery_yes            ...              0.073914       -0.094132
# higher_yes             ...              0.080524       -0.198100
# internet_yes           ...             -0.024990        0.023074
# romantic_yes           ...             -0.017849        0.130019
#
#                    schoolsup_yes  famsup_yes  paid_yes  activities_yes  \
# age                    -0.167841   -0.101894 -0.005458       -0.054279
# Medu                   -0.022168    0.120491  0.113973        0.119354
# Fedu                    0.023572    0.135191  0.094628        0.079700
# traveltime             -0.044807   -0.039289 -0.044842       -0.033376
# studytime               0.089316    0.143509 -0.002314        0.070080
# school_MS             0.004659   -0.136112     -0.240486      0.072241
# sex_M                -0.043603   -0.058134      0.065911     -0.110144
# address_U             0.018077    0.076706      0.175794     -0.030939
# famsize_LE3           0.100686    0.004523      0.013357     -0.032936
# Pstatus_T            -0.032724    0.022726      0.059754     -0.053828
# Mjob_health           0.036501    0.097475      0.085946      0.016156
# Mjob_other           -0.087954   -0.026252     -0.066857      0.039095
# Mjob_services         0.026858    0.042486      0.149119     -0.063447
# Mjob_teacher          0.076450    0.105923      0.148069     -0.045922
# Fjob_health           0.053120    0.039076      0.006929     -0.025398
# Fjob_other           -0.020451   -0.019982      0.002857      0.005471
# Fjob_services        -0.011243    0.025007      0.049705     -0.018912
# Fjob_teacher         -0.015223    0.061747      0.005990      0.024321
# reason_home          -0.024062    0.045657      0.066481      0.000983
# reason_other          0.002470   -0.053244     -0.049326      0.035453
# reason_reputation     0.048614    0.098936      0.107965     -0.066754
# guardian_mother       0.073914    0.080524     -0.024990     -0.017849
# guardian_other       -0.094132   -0.198100      0.023074      0.130019
# schoolsup_yes         0.017846    0.085355     -0.025942     -0.094310
# famsup_yes            0.027799    0.085340      0.071891     -0.023398
# paid_yes              0.027566    0.024112      0.031823     -0.018309
# activities_yes        0.039719    0.044908      0.082375      0.057517
# nursery_yes           1.000000    0.042605     -0.007159     -0.022984
# higher_yes            0.042605    1.000000      0.070345     -0.099389
# internet_yes         -0.007159    0.070345      1.000000      0.034832
# romantic_yes         -0.022984   -0.099389      0.034832      1.000000
#
# [42 rows x 42 columns]

# %% [markdown]
# ## Variance Inflation Factor
# Analyzing the correlation between variables is not enough. It is very beneficial to access which variables inflate the variance the most. Since models with minimum variance are optimal we will remove variables that inflate variance the most. In general a VIF bigger than or equal to 10 is considered high VIF and thus, the associated variable should be removed from the design matrix.

# %%
#no_dummy_df = pd.read_csv("student-por2")

def var_if_fac(data_frame, ind_var):
    index = data_frame.columns.get_loc(ind_var)
    mat = data_frame.as_matrix()
    return(vif(mat, index))

no_response = df.drop('G3',1)
arr1 = []
arr2 = list(no_response)

for i in list(no_response):
    arr1.append(var_if_fac(no_response,i))
vif_df = pd.DataFrame(list(zip(arr2,arr1)),columns = ['Ind_Var','VIF'])
vif_df
# Out:
#               Ind_Var        VIF
# 0                 age  92.485829
# 1                Medu  15.909121
# 2                Fedu  11.305630
# 3          traveltime   6.747138
# 4           studytime   8.042191
# 5            failures   1.620601
# 6              famrel  19.965318
# 7            freetime  12.451270
# 8               goout  12.117377
# 9                Dalc   6.680433
# 10               Walc   8.768801
# 11             health   7.956884
# 12           absences   1.987674
# 13                 G1  77.636654
# 14                 G2  72.035157
# 15          school_MS   2.308016
# 16              sex_M   2.355332
# 17          address_U   4.287215
# 18        famsize_LE3   1.627001
# 19          Pstatus_T   9.527880
# 20        Mjob_health   1.953215
# 21         Mjob_other   3.323545
# 22      Mjob_services   2.673254
# 23       Mjob_teacher   2.556247
# 24        Fjob_health   1.803108
# 25         Fjob_other  10.432376
# 26      Fjob_services   5.673580
# 27       Fjob_teacher   2.280769
# 28        reason_home   1.706108
# 29       reason_other   1.370773
# 30  reason_reputation   1.792020
# 31    guardian_mother   4.504410
# 32     guardian_other   1.608504
# 33      schoolsup_yes   1.254922
# 34         famsup_yes   2.864689
# 35           paid_yes   1.173340
# 36     activities_yes   2.214079
# 37        nursery_yes   5.376670
# 38         higher_yes  12.030233
# 39       internet_yes   5.357845
# 40       romantic_yes   1.780107

# %% [markdown]
# # Remove Correlated Variables/Transform Response Variable
# The variables *G1*, *G2*, and *G3* had the higest correlation and thus we will exclude *G1* and *G2* from the design matrix. We keep *G3* becasue that is our response variable. We will also create our multidemonsional design matrix and 1-demensional response variable in this step. Lastly we start with defining a function *response_conv()* to transform our diescrete response variable to binary.

# %%
def response_conv(arr):
    new = []
    for i in arr:
        if (i > 0 and i < 10):           # condition where student failed
            new.append(0)                 
                                          
        elif (i >= 10):                   # condition where student passed
            new.append(1)                 
    
        else:                             # condition where student received an incomplete
            new.append(2)
    return(new)                           # 1-dimensional response varibale returned

drop_col_names = []

vifs = list(vif_df.VIF)
predictors = list(vif_df.Ind_Var)

for i in range(len(predictors)):
    if vifs[i] >= 10:
        drop_col_names.append(predictors[i])
        
df = df.drop(drop_col_names,1)            # This is the data frame with high VIF variables removed
X = df.drop('G3',1)                       # This is the design matrix
y = list(df.G3)                           # This is the discrete response vector
y_new = response_conv(y)                  # This is the multinomial response vector
X_scale = preprocessing.scale(X)
X_norm = preprocessing.normalize(X)
print (X.shape)
# Out:
# (649, 31)

# %% [markdown]
# ## Fit Model/Split Data
# Here we split the data into a training set and a test set, then fit the logistic regression model.

# %%
X1_train, X1_test, y1_train, y1_test = train_test_split(X, y_new, test_size=0.33, random_state=42)
"""
start_time = time.time()
combos = cartesian([['multinomial','ovr'],['newton-cg', 'lbfgs', 'sag']])

def opt(X,y):
    mse = []

    for mc,s in combos:
        lr = LogisticRegression(multi_class=mc,solver=s)
        scores = cross_val_score(lr, X, y, cv=10, scoring='neg_mean_squared_error')
        mse.append(scores.mean())
    
    #MSE = [1 - x for x in cv_scores]
    opt_ = combos[mse.index(min(mse))]
    return(opt_)
mc,s = opt(X1_train,y1_train)
print(mc,s)
"""
log_reg1 = LogisticRegression().fit(X1_train, y1_train)

# %% [markdown]
# ## Estimated Coefficients
# Due to the multinomial nature of the response variable, each estimated coefficient is displayed in a vector consisting of 3 components, one for each response category. The follwing output captures this notion.

# %%
coef_df = pd.DataFrame(list(zip(X1_train.columns, np.transpose(np.round(log_reg1.coef_,2)))))
coef_df
# Out:
#                     0                     1
# 0          traveltime  [-0.28, 0.24, -0.05]
# 1           studytime  [-0.33, 0.37, -0.62]
# 2            failures   [0.85, -1.03, 1.07]
# 3                Dalc   [0.07, -0.11, 0.16]
# 4                Walc  [0.05, -0.03, -0.16]
# 5              health  [-0.07, 0.04, -0.08]
# 6            absences  [0.09, -0.06, -1.24]
# 7           school_MS    [1.39, -1.6, 1.17]
# 8               sex_M   [0.25, -0.23, 0.09]
# 9           address_U  [-0.16, 0.35, -0.83]
# 10        famsize_LE3   [-0.31, 0.5, -1.02]
# 11          Pstatus_T  [-0.23, 0.38, -0.57]
# 12        Mjob_health   [0.08, 0.05, -0.47]
# 13         Mjob_other  [-0.16, 0.08, -0.07]
# 14      Mjob_services  [-0.01, -0.0, -0.06]
# 15       Mjob_teacher   [-0.88, 0.58, 0.57]
# 16        Fjob_health  [0.78, -0.78, -0.03]
# 17      Fjob_services   [0.17, -0.26, 0.26]
# 18       Fjob_teacher   [-0.0, -0.38, 0.55]
# 19        reason_home    [-0.3, 0.03, 0.35]
# 20       reason_other  [-0.21, -0.14, 0.94]
# 21  reason_reputation  [-0.81, 0.59, -0.04]
# 22    guardian_mother    [0.6, -0.55, -0.1]
# 23     guardian_other   [-0.39, 0.43, -0.4]
# 24      schoolsup_yes   [0.37, -0.43, 0.18]
# 25         famsup_yes   [0.01, 0.17, -0.72]
# 26           paid_yes    [0.11, -0.1, -0.0]
# 27     activities_yes   [-0.37, 0.27, 0.27]
# 28        nursery_yes  [0.13, -0.16, -0.42]
# 29       internet_yes    [-0.2, 0.2, -0.34]
# 30       romantic_yes   [0.19, -0.2, -0.08]

# %% [markdown]
# ## Probability Per Category
# Each observation is assigned a probability for each respective response category. In our case each observation will then have 3 probabilities, one for student failing (0), one for student passing (1), and one for student receiving an incomplete (2). The following table is a snipit of each observations probability for each respective category. **Note** each row sums to 1.

# %%
pred_prob = log_reg1.predict_proba(X1_test)
prob_df = pd.DataFrame(np.round(pred_prob,4), columns = ['prob_fail','prob_pass', 'prob_inc'])
prob_df.index.name = 'Obs'
prob_df
# Out:
#      prob_fail  prob_pass  prob_inc
# Obs
# 0       0.0594     0.9387    0.0019
# 1       0.0904     0.9089    0.0007
# 2       0.0223     0.8294    0.1483
# 3       0.3812     0.6187    0.0001
# 4       0.0548     0.9442    0.0010
# 5       0.0931     0.9068    0.0001
# 6       0.0379     0.9492    0.0128
# 7       0.4494     0.5506    0.0000
# 8       0.1241     0.8759    0.0000
# 9       0.0535     0.9465    0.0001
# 10      0.0269     0.9526    0.0205
# 11      0.0673     0.8847    0.0480
# 12      0.0189     0.9754    0.0057
# 13      0.0495     0.9495    0.0010
# 14      0.1175     0.8799    0.0026
# 15      0.0204     0.9753    0.0043
# 16      0.0285     0.9634    0.0081
# 17      0.1034     0.8965    0.0000
# 18      0.0080     0.9920    0.0000
# 19      0.0335     0.9658    0.0007
# 20      0.0791     0.9149    0.0060
# 21      0.0349     0.9575    0.0076
# 22      0.0089     0.9909    0.0002
# 23      0.0832     0.8817    0.0351
# 24      0.1611     0.8018    0.0371
# 25      0.0206     0.9626    0.0167
# 26      0.2018     0.7929    0.0053
# 27      0.0163     0.9835    0.0002
# 28      0.0983     0.8959    0.0058
# 29      0.0230     0.9764    0.0006
# ..         ...        ...       ...
# 185     0.0979     0.9021    0.0000
# 186     0.0250     0.9742    0.0008
# 187     0.0648     0.9332    0.0020
# 188     0.0687     0.8782    0.0531
# 189     0.0187     0.9674    0.0139
# 190     0.0744     0.9256    0.0000
# 191     0.3869     0.6131    0.0000
# 192     0.3644     0.6356    0.0000
# 193     0.2043     0.7957    0.0000
# 194     0.0508     0.9492    0.0000
# 195     0.3520     0.6222    0.0258
# 196     0.0369     0.9631    0.0000
# 197     0.0302     0.9610    0.0089
# 198     0.4608     0.5373    0.0019
# 199     0.0368     0.9632    0.0000
# 200     0.0219     0.9770    0.0011
# 201     0.2129     0.7738    0.0133
# 202     0.3389     0.6611    0.0000
# 203     0.0174     0.9816    0.0011
# 204     0.0403     0.9583    0.0014
# 205     0.0639     0.9201    0.0160
# 206     0.1528     0.8472    0.0000
# 207     0.0156     0.9751    0.0093
# 208     0.0480     0.9500    0.0020
# 209     0.0164     0.9814    0.0022
# 210     0.3863     0.6134    0.0003
# 211     0.5941     0.4009    0.0050
# 212     0.0371     0.9562    0.0067
# 213     0.0611     0.9383    0.0006
# 214     0.0749     0.9248    0.0003
#
# [215 rows x 3 columns]

# %% [markdown]
# ## Model Prediction vs. Actual Response Value
# The following is the comparrison of the predictions made by our model (y_pred) and the actual response values (y_act), on the testing data set.

# %%
log_pred1 = log_reg1.predict(X1_test)

pred = pd.DataFrame(list(zip(y1_test, log_pred1)), columns=['y_act','y_log'])
pred.index.name = 'Obs'

#pred.to_csv("preds.csv")
pred
# Out:
#      y_act  y_log
# Obs
# 0        1      1
# 1        1      1
# 2        1      1
# 3        1      1
# 4        1      1
# 5        1      1
# 6        1      1
# 7        0      1
# 8        1      1
# 9        1      1
# 10       1      1
# 11       1      1
# 12       1      1
# 13       0      1
# 14       1      1
# 15       1      1
# 16       1      1
# 17       0      1
# 18       1      1
# 19       1      1
# 20       1      1
# 21       1      1
# 22       1      1
# 23       1      1
# 24       1      1
# 25       1      1
# 26       0      1
# 27       1      1
# 28       1      1
# 29       1      1
# ..     ...    ...
# 185      1      1
# 186      1      1
# 187      0      1
# 188      1      1
# 189      1      1
# 190      1      1
# 191      0      1
# 192      1      1
# 193      1      1
# 194      1      1
# 195      0      1
# 196      1      1
# 197      1      1
# 198      1      1
# 199      1      1
# 200      1      1
# 201      1      1
# 202      1      1
# 203      1      1
# 204      1      1
# 205      1      1
# 206      1      1
# 207      1      1
# 208      1      1
# 209      1      1
# 210      0      1
# 211      1      0
# 212      1      1
# 213      1      1
# 214      1      1
#
# [215 rows x 2 columns]

# %% [markdown]
# ## Model Accuracy and Confusion Matrix
# Lastly we output the models overall accuracy and confusion matrix.

# %%
cm_log1 = pd.DataFrame(metrics.confusion_matrix(y1_test, log_pred1), index = ['Fail(0)','Pass(1)','Inc(2)'],columns=['Fail(0)','Pass(1)','Inc(2)'])
print ("The accuracy of the Logistic Regression model is: ", log_reg1.score(X1_test,y1_test))
print("\n")
print("Logistic Regression Confusion Matrix: \n\n", cm_log1)
# Out:
# The accuracy of the Logistic Regression model is:  0.86976744186
#
#
# Logistic Regression Confusion Matrix:
#
#           Fail(0)  Pass(1)  Inc(2)
# Fail(0)        3       20       0
# Pass(1)        4      183       0
# Inc(2)         1        3       1
